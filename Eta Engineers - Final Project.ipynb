# %% [markdown]
# # **Marketing Series : Customer Lifetime Value**
# ****
# ### Created by : Eta Engineers

# %% [markdown]
# ## Content :
#
# 1. Business Problem Understanding
# 2. Data Understanding
# 3. Explanatory Data Analysis
# 4. Preprocessing
# 5. Modeling & Analysis
# 6. Conclusion and Recomendation

# %% [markdown]
# ## **1. Business Problem Understanding**
# ****

# %% [markdown]
# **Context**
#
# An Auto Insurance company in the USA is facing issues in retaining its customers and wants to advertise promotional offers for its loyal customers. They are considering Customer Lifetime Value (CLV) as a parameter for this purpose. Customer Lifetime Value represents a customer’s value to a company over a period of time. It’s a competitive market for insurance companies, and the insurance premium isn’t the only determining factor in a customer’s decisions. CLV is a customer-centric metric, and a powerful base to build upon to retain valuable customers, increase revenue from less valuable customers, and improve the customer experience overall. Using CLV effectively can improve customer acquisition and customer retention, prevent churn, help the company to plan its marketing budget, measure the performance of their ads in more detail, and much more.
# <br>
# <br>
#
# Sebuah perusahaan Asuransi Kendaraan di AS menghadapi masalah dalam mempertahankan pelanggannya dan ingin mengiklankan penawaran promosi untuk pelanggan setianya. Mereka mempertimbangkan CLV Nilai Seumur Hidup Pelanggan sebagai parameter untuk tujuan ini. Nilai Seumur Hidup Pelanggan mewakili nilai pelanggan bagi perusahaan selama periode waktu tertentu. Ini adalah pasar yang kompetitif bagi perusahaan asuransi, dan premi asuransi bukan satu-satunya faktor penentu dalam keputusan pelanggan.
#
# CLV adalah metrik yang berpusat pada pelanggan, dan dasar yang kuat untuk membangun untuk mempertahankan pelanggan yang berharga, meningkatkan pendapatan dari pelanggan yang kurang berharga, dan meningkatkan pengalaman pelanggan secara keseluruhan.
#
# Menggunakan CLV secara efektif dapat meningkatkan akuisisi pelanggan dan retensi pelanggan, mencegah churn, membantu perusahaan merencanakan anggaran pemasarannya, mengukur kinerja iklan mereka secara lebih detail, dan banyak lagi.

# %% [markdown]
# Define Problem  :
# 1. Siapa yang mengalami masalah? Sebuah perusahaan Asuransi Kendaraan di AS.
# <br>
# <br>
# 2. Masalahnya apa? (specific, measurable)  retaining its customers and wants to advertise promotional offers for its loyal customers.
# <br>
# <br>
# 3. Mengapa masalahnya penting untuk dipecahkan? (specific, measurable) untuk membangun dan mempertahankan pelanggan yang berharga, meningkatkan pendapatan dari pelanggan yang kurang berharga, dan meningkatkan pengalaman pelanggan secara keseluruhan.
# <br>
# <br>
# 4. Tujuan/target dari penyelesaian masalah tersebut? (specific, measurable, achievable) meningkatkan akuisisi pelanggan dan retensi pelanggan, mencegah churn, membantu perusahaan merencanakan anggaran pemasarannya, mengukur kinerja iklan mereka secara lebih detail, dan banyak lagi.

# %% [markdown]
# **Problem Statement for Machine Learning**
#
# How to predict automotive insurance customer lifetime value so the Auto Insurance company can increase revenue?

# %% [markdown]
# **Problem Statement for Analytics**
#
# What customes should we targeting in order to increase revenue?

# %% [markdown]
# **Problem Statement :** <br>
# Proses pengiklanan, promosi, ataupun penawaran lainnya akan memakan waktu dan sumber daya yang lebih jika perusahaan menargetkan semua pelanggan tanpa melakukan penyaringan terlebih dahulu.
#
# Secara umum, customer lifetime value ini akan membantu perusahaan untuk mempertahankan pelanggan yang ada. Sebab mendapatkan pelanggan baru jauh lebih sulit dan membutuhkan waktu serta biaya lebih besar dibanding mempertahankan yang sudah ada. Selain itu, memahami customer lifetime value juga akan membantu bisnis perusahaan untuk mengembangkan strategi pengiklanan, promosi, ataupun penawaran sambil di sisi lain bisa mempertahankan margin keuntungan tetap stabil.

# %% [markdown]
# **Goals :** <br>
# Maka berdasarkan permasalahan tersebut, perusahaan asuransi ini perlu memiliki 'tool' yang dapat memprediksi parameter-parameter mana saja dibutuhkan untuk mempertahankan pelanggan yang berharga, meningkatkan pendapatan dari pelanggan yang kurang berharga, dan meningkatkan pengalaman pelanggan secara keseluruhan.

# %% [markdown]
# **Analytic Approach :** <br>
# Jadi, yang perlu dilakukan adalah menganalisis data untuk dapat menemukan pola dari fitur-fitur yang ada, yang membedakan satu fitur dengan yang lainnya.
# Selanjutnya, kita akan membangun suatu model regresi yang akan membantu perusahaan asuransi untuk mendapatkan 'tool' prediksi customer lifetime value yang bertujuan untuk mempertahankan pelanggan yang berharga, meningkatkan pendapatan dari pelanggan yang kurang berharga, dan meningkatkan pengalaman pelanggan secara keseluruhan.

# %% [markdown]
# **Metric Evaluation**
#
# Evaluasi metrik yang akan digunakan adalah RMSE, MAE, dan MAPE, di mana RMSE adalah nilai rataan akar kuadrat dari error, MAE adalah rataan nilai absolut dari error, sedangkan MAPE adalah rataan persentase error yang dihasilkan oleh model regresi. Semakin kecil nilai RMSE, MAE, dan MAPE yang dihasilkan, berarti model semakin akurat dalam memprediksi harga sewa sesuai dengan limitasi fitur yang digunakan.
#
# Selain itu, kita juga bisa menggunakan nilai R-squared atau adj. R-squared jika model yang nanti terpilih sebagai final model adalah model linear. Nilai R-squared digunakan untuk mengetahui seberapa baik model dapat merepresentasikan varians keseluruhan data. Semakin mendekati 1, maka semakin fit pula modelnya terhadap data observasi. Namun, metrik ini tidak valid untuk model non-linear.

# %% [markdown]
# ## **2. Data Understanding**
# ****

# %% [markdown]
# Dataset Source : https://www.kaggle.com/datasets/arashnic/marketing-seris-customer-lifetime-value?select=squark_automotive_CLV_training_data.csv

# %% [markdown]
# ### Attribute Information
#
#
#
#
# | Attribute | Data Type, Length | Description |
# | --- | --- | --- |
# | Customer | Text | ID Customer |
# | State | Text | Region |
# | Customer Lifetime Value | Float | Customer Lifetime Value (Target) |
# | Response | Text | Menanggapi panggilan pemasaran |
# | Coverage | Text | Jenis Pertanggungan Asuransi Kendaraan |
# | Education | Text | Pendidikan |
# | Effective To Date | Text | Tanggal asuransi mulai berlaku |
# | Employment Status | Text | Status Pekerjaan |
# | Gender | Text | Female/Male |
# | Income | Float | Pendapatan (Dollar) |
# | Location Code | Text | Wilayah Geografis tempat tinggal |
# | Marital Status | Text | Status Pernikahan |
# | Monthly Premium Auto | Float | Tagihan perbulan |
# | Months Since Last Claim | Float | Jumlah Bulan Sejak klaim terakhir |
# | Months Since Policy Inception | Float | Jumlah Bulan ------ |
# | Number of Open Complaints | Float | Jumlah komplain yang masih berjalan |
# | Number of Policies | Float | Nomor polis |
# | Policy Type | Text | Tipe perjanjian asuransi |
# | Policy | Text | Perjanjian asuransi |
# | Renew Offer Type | Text | Penawaran untuk perbarui polis yang sudah/akan habis |
# | Sales Channel | Text | cara atau media yang ditempuh untuk menjual produk |
# | Total Claim Amount | Float | Total uang yang ditanggung oleh Asuransi |
# | Vehicle Class | Text | Klasifikasi Tipe Kendaraan |
# | Vehicle Size | Text | Ukuran kendaraan |

# %%
import pandas as pd
import numpy as np
import missingno
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv('squark_automotive_CLV_training_data.csv')
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129      NaN         NaN                      NaN      NaN       NaN
# 9130      NaN         NaN                      NaN      NaN       NaN
# 9131      NaN         NaN                      NaN      NaN       NaN
# 9132      NaN         NaN                      NaN      NaN       NaN
# 9133      NaN         NaN                      NaN      NaN       NaN
#
#      Education Effective To Date EmploymentStatus Gender   Income  ...  \
# ...

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2),
                    df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#                      dataFeatures dataType  null  nullPct  unique  \
# 0                        Customer   object  1035    11.33    8099
# 1                           State   object  1035    11.33       5
# 2         Customer Lifetime Value  float64  1035    11.33    7142
# 3                        Response   object  1035    11.33       2
# 4                        Coverage   object  1035    11.33       3
# 5                       Education   object  1035    11.33       5
# 6               Effective To Date   object  1035    11.33      59
# 7                EmploymentStatus   object  1035    11.33       5
# 8                          Gender   object  1035    11.33       2
# 9                          Income  float64  1035    11.33    5090
# 10                  Location Code   object  1035    11.33       3
# 11                 Marital Status   object  1035    11.33       3
# 12           Monthly Premium Auto  float64  1035    11.33     197
# ...

# %% [markdown]
# Dari deskripsi data diatas terdapat missing value yang terdapat pada setiap Row dan juga data yang memiliki type data yang salah. masalah ini akan kita selesaikan pada Data Cleaning.

# %% [markdown]
# ### **2.1 Data Cleaning**
# ****

# %% [markdown]
# #### **Missing Value**
# ****

# %% [markdown]
# #### Visualisasi Missing Value

# %%
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.dropna(axis = 0, inplace=True)
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 8094  UH22701      Oregon              9726.551005       No  Extended
# 8095  IA85970  California              8099.466122       No     Basic
# 8096  TC18240      Oregon              5020.473987       No     Basic
# 8097  GE58317     Arizona              4834.710493      Yes     Basic
# 8098  GW42895      Oregon             17625.537630       No     Basic
#
#      Education Effective To Date EmploymentStatus Gender   Income  ...  \
# ...

# %% [markdown]
# #### **Duplicated Data**
# ****

# %%
df[df.duplicated(subset=None, keep=False) == True].head()
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Menunjukan tidak ada data yang terduplikasi

# %% [markdown]
# #### **Format Correction**
# ****

# %%
df['Effective To Date']=pd.to_datetime(df['Effective To Date'],infer_datetime_format=True)

# %%
df["Months"] = df["Effective To Date"].dt.month
df['Months'] = df['Months'].astype('object')

# %% [markdown]
# #### **Cleaned Data**
# ****

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2),
                    df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#                      dataFeatures        dataType  null  nullPct  unique  \
# 0                        Customer          object     0      0.0    8099
# 1                           State          object     0      0.0       5
# 2         Customer Lifetime Value         float64     0      0.0    7142
# 3                        Response          object     0      0.0       2
# 4                        Coverage          object     0      0.0       3
# 5                       Education          object     0      0.0       5
# 6               Effective To Date  datetime64[ns]     0      0.0      59
# 7                EmploymentStatus          object     0      0.0       5
# 8                          Gender          object     0      0.0       2
# 9                          Income         float64     0      0.0    5090
# 10                  Location Code          object     0      0.0       3
# 11                 Marital Status          object     0      0.0       3
# ...

# %% [markdown]
# ## **3. Explanatory Data Analysis**
# ****

# %%
df_eda = df.copy()

# %% [markdown]
# ### 1. Univariate Analysis

# %% [markdown]
# ### 1.1 Feature Income

# %%
f = plt.figure(figsize=(10,8))

f.add_subplot(2,1,1)
sns.distplot(df_eda['Income'])
c = df_eda['Income'].mean()
d = df_eda['Income'].median()
plt.axvline(df_eda['Income'].mean(), label= (f'mean={c}'))
plt.axvline(df_eda['Income'].median(), label =(f'median={d}'))
plt.legend()

f.add_subplot(2,1,2)
sns.boxplot(df['Income'], color='green')
plt.show()
# plt.savefig('./storage/fitur loan1.png')

# %% [markdown]
# Berdasarkan Grafik diatas:
#
# 1. Terilihat data tidak terdistribusi normal
# 2. Nilai median income sebesar 34.430 USD

# %% [markdown]
# ### 1.2 Feature Location Code

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Location Code', data =df)
print('Konsumen pada area Suburban', df['Location Code'].value_counts()['Suburban'])
print('Konsumen pada area Rural', df['Location Code'].value_counts()['Rural'])
print('Konsumen pada area Urban', df['Location Code'].value_counts()['Urban'])
plt.show()
# Out:
# Konsumen pada area Suburban 5098
# Konsumen pada area Rural 1598
# Konsumen pada area Urban 1403

# %% [markdown]
# Berdasarkan Countplot diatas, pengguna asuransi kendaraan terbanyak berasal dari area Suburban dan pengguna asuransi kendaraan terkecil berada pada area Urban.

# %% [markdown]
# ### 1.3 Feature Marital Status

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Marital Status', data =df_eda)
print('Jumlah Konsumen dengan status Married', df_eda['Marital Status'].value_counts()['Married'])
print('Jumlah Konsumen dengan status Single', df_eda['Marital Status'].value_counts()['Single'])
print('Jumlah Konsumen dengan status Divorced', df_eda['Marital Status'].value_counts()['Divorced'])
plt.show()
# Out:
# Jumlah Konsumen dengan status Married 4728
# Jumlah Konsumen dengan status Single 2153
# Jumlah Konsumen dengan status Divorced 1218

# %% [markdown]
# ### 1.4 Feature Monthly Premium Auto

# %%
f = plt.figure(figsize=(10,8))

f.add_subplot(2,1,1)
sns.distplot(df_eda['Monthly Premium Auto'])
c = df_eda['Monthly Premium Auto'].mean()
d = df_eda['Monthly Premium Auto'].median()
plt.axvline(df_eda['Monthly Premium Auto'].mean(), label= (f'mean={c}'))
plt.axvline(df_eda['Monthly Premium Auto'].median(), label =(f'median={d}'))
plt.legend()

f.add_subplot(2,1,2)
sns.boxplot(df_eda['Monthly Premium Auto'], color='green')
plt.show()
# plt.savefig('./storage/fitur loan1.png')

# %% [markdown]
# Berdasarkan Grafik diatas:
#
# 1. Terilihat data tidak terdistribusi normal
# 2. Nilai median Monthly Premium Auto sebesar 83
# 3. Data memiliki cukup banyak outlier, hal ini cukup masuk akal karena nilai premi ini berdasarkan harga kendaraan dan tidak banyak yang memiliki kendaraan yang mewah atau mahal.

# %% [markdown]
# ### 1.5 Feature Months Since Last Claim

# %%
f = plt.figure(figsize=(10,8))

f.add_subplot(2,1,1)
sns.distplot(df_eda['Months Since Last Claim'])
c = df_eda['Months Since Last Claim'].mean()
d = df_eda['Months Since Last Claim'].median()
plt.axvline(df_eda['Months Since Last Claim'].mean(), label= (f'mean={c}'))
plt.axvline(df_eda['Months Since Last Claim'].median(), label =(f'median={d}'))
plt.legend()

f.add_subplot(2,1,2)
sns.boxplot(df_eda['Months Since Last Claim'], color='green')
plt.show()
# plt.savefig('./storage/fitur loan1.png')

# %% [markdown]
# Berdasarkan Grafik diatas:
#
# 1. Terilihat data tidak terdistribusi normal
# 2. Nilai median Months Since Last Claim sebesar 14

# %% [markdown]
# ### 1.6 Feature Months Since Policy Inception

# %%
f = plt.figure(figsize=(10,8))

f.add_subplot(2,1,1)
sns.distplot(df_eda['Months Since Policy Inception'])
c = df_eda['Months Since Policy Inception'].mean()
d = df_eda['Months Since Policy Inception'].median()
plt.axvline(df_eda['Months Since Policy Inception'].mean(), label= (f'mean={c}'))
plt.axvline(df_eda['Months Since Policy Inception'].median(), label =(f'median={d}'))
plt.legend()

f.add_subplot(2,1,2)
sns.boxplot(df_eda['Months Since Policy Inception'], color='green')
plt.show()
# plt.savefig('./storage/fitur loan1.png')

# %% [markdown]
# Berdasarkan Grafik diatas:
#
# 1. Terilihat data tidak terdistribusi normal
# 2. Nilai median Months Since Policy Inception sebesar 48

# %% [markdown]
# ### 1.7 Feature Number of Open Complaints

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Number of Open Complaints', data =df_eda)
#print('Konsumen pada area Suburban', df['Marital Status'].value_counts()['Married'])
#print('Konsumen pada area Rural', df['Marital Status'].value_counts()['Single'])
#print('Konsumen pada area Urban', df['Marital Status'].value_counts()['Divorced'])
plt.show()

# %% [markdown]
# ### 2. Bivariate Analysis

# %% [markdown]
# ### 2.1 Feature Income, Monthly Premium Auto and Customer Lifetime Value

# %%
f = plt.figure(figsize=(10,10))

f.add_subplot(2,1,1)
sns.scatterplot(y = 'Customer Lifetime Value', x = 'Income', data =df_eda)
sns.despine(bottom=True, left=True)


f.add_subplot(2,1,2)
sns.scatterplot(y = 'Customer Lifetime Value', x = 'Monthly Premium Auto', data =df_eda)
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ### 2.2 Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints and Customer Lifetime Value

# %%
f = plt.figure(figsize=(10,10))

f.add_subplot(3,1,1)
sns.scatterplot(y = 'Customer Lifetime Value', x = 'Months Since Last Claim', data =df_eda)
sns.despine(bottom=True, left=True)


f.add_subplot(3,1,2)
sns.scatterplot(y = 'Customer Lifetime Value', x = 'Months Since Policy Inception', data =df_eda)
sns.despine(bottom=True, left=True)

f.add_subplot(3,1,3)
sns.scatterplot(y = 'Customer Lifetime Value', x = 'Number of Open Complaints', data =df_eda)
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ### 2.3 Location Code, Marital Status and Customer Lifetime Value

# %%
f = plt.figure(figsize=(10,10))

f.add_subplot(2,1,1)
sns.barplot(y='Customer Lifetime Value', x= 'Location Code', data=df_eda, estimator=np.median)


f.add_subplot(2,1,2)
sns.barplot(y='Customer Lifetime Value', x= 'Marital Status', data=df_eda, estimator=np.median)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder  
k=15  
data = df
labelencoder1_corr = LabelEncoder().fit(data.iloc[:,0])  
data.iloc[:,0] = labelencoder1_corr.transform(data.iloc[:,0])                     
corrmat = data.corr()    
top_corr_features = corrmat.index      
plt.figure(figsize=(20,20))
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# plt.savefig('./storage/korelasi.png')
